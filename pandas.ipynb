# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("services.csv")

# %%
df.head(5)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df['website']
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21    http://www.example.com
# 22    http://www.example.com
# Name: website, dtype: object

# %%
type(df['website'])
# Out:
# pandas.core.series.Series

# %%
list(df['website'])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'http://www.example.com',
#  'http://www.example.com']

# %%
df[['website']]
# Out:
#                    website
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# 12                     NaN
# 13                     NaN
# 14                     NaN
# 15                     NaN
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21  http://www.example.com
# 22  http://www.example.com

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[['location_id', 'program_id']]
# Out:
#     location_id  program_id
# 0             1         NaN
# 1             2         NaN
# 2             3         NaN
# 3             4         NaN
# 4             5         NaN
# 5             6         NaN
# 6             7         NaN
# 7             8         NaN
# 8             9         NaN
# 9            10         NaN
# 10           11         NaN
# 11           12         NaN
# 12           13         NaN
# 13           14         NaN
# 14           15         NaN
# 15           16         NaN
# 16           17         NaN
# 17           18         NaN
# 18           19         NaN
# 19           20         NaN
# 20           21         NaN
# 21           22         NaN
# 22           22         NaN

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df1=pd.read_csv("HR_Analytics.csv")

# %%
df1
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# EmpID                        object
# Age                           int64
# AgeGroup                     object
# Attrition                    object
# BusinessTravel               object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome                 int64
# SalarySlab                   object
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# Over18                       object
# OverTime                     object
# ...

# %%
df1.columns
# Out:
# Index(['EmpID', 'Age', 'AgeGroup', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'SalarySlab',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df1[['EmpID', 'Age', 'AgeGroup']]
# Out:
#        EmpID  Age AgeGroup
# 0      RM297   18    18-25
# 1      RM302   18    18-25
# 2      RM458   18    18-25
# 3      RM728   18    18-25
# 4      RM829   18    18-25
# ...      ...  ...      ...
# 1475   RM412   60      55+
# 1476   RM428   60      55+
# 1477   RM537   60      55+
# 1478   RM880   60      55+
# 1479  RM1210   60      55+
#
# [1480 rows x 3 columns]

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2['PassengerId']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
type(df2['PassengerId'])
# Out:
# pandas.core.series.Series

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 53.9 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df2[['PassengerId','Fare', 'Cabin']]
# Out:
#      PassengerId     Fare Cabin
# 0              1   7.2500   NaN
# 1              2  71.2833   C85
# 2              3   7.9250   NaN
# 3              4  53.1000  C123
# 4              5   8.0500   NaN
# ..           ...      ...   ...
# 886          887  13.0000   NaN
# 887          888  30.0000   B42
# 888          889  23.4500   NaN
# 889          890  30.0000  C148
# 890          891   7.7500   NaN
#
# [891 rows x 3 columns]

# %%
import lxml
import pandas as pd
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3=url_data[0]

# %%
df3
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3[['Player', 'Pos', 'Age']]
# Out:
#              Player Pos Age
# 0        Quincy Acy  PF  24
# 1      Jordan Adams  SG  20
# 2      Steven Adams   C  21
# 3       Jeff Adrien  PF  28
# 4     Arron Afflalo  SG  29
# ..              ...  ..  ..
# 670  Thaddeus Young  PF  26
# 671  Thaddeus Young  PF  26
# 672  Thaddeus Young  PF  26
# 673     Cody Zeller   C  22
# 674    Tyler Zeller   C  25
#
# [675 rows x 3 columns]

# %%
df3.to_csv("playes_data.csv",index=False)

# %%
#day 2
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
list(df.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[df.dtypes[df.dtypes=="float64"].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Ticket",'Survived']][0:11:2]
# Out:
#               Ticket  Survived
# 0          A/5 21171         0
# 2   STON/O2. 3101282         1
# 4             373450         0
# 6              17463         0
# 8             347742         1
# 10           PP 9549         1

# %%
df["new_col"]=0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["new_col1"]=df['Survived']+df['Pclass']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col1
# 0      0         A/5 21171   7.2500   NaN        S        0         3
# 1      0          PC 17599  71.2833   C85        C        0         2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0         4
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Age']>17
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age']>17]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df['Age']>17)
# Out:
# 891

# %%
df['Fare']>7.2500
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']>7.2500]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df['Fare']>32
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[(df['Sex'] == 'female') & (df['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex'] == 'female') | (df['Fare']>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['PassengerId','Survived','Pclass','Name']][0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
df.iloc[0:2,['PassengerId','Survived','Pclass','Name']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df.iloc[0:2,['PassengerId','Survived','Pclass','Name']]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[0:2,['PassengerId','Survived','Pclass','Name']]

# %%
df.iloc[0:2,[0,1,2,3]]

# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s=df['Name'][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
len(s)
# Out:
# 10

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
l=['a','b','c','d','e','f','g','h','i','j']

# %%
s1=pd.Series(list(s),index=l)

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s1
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2=s1.append(s)
# Out:
# /tmp/ipykernel_126/2552242485.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2=s1.append(s)

# %%
s2[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2[4]
# Out:
# 'Allen, Mr. William Henry'

# %%
s4=pd.Series([3,4,5,6,6],index=[2,9,5,6,1])

# %%
s5=pd.Series([35,4,56,56,36],index=[22,9,252,63,12])

# %%
s6=s4.append(s5)
# Out:
# /tmp/ipykernel_126/884104408.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s6=s4.append(s5)

# %%
s6
# Out:
# 2       3
# 9       4
# 5       5
# 6       6
# 1       6
# 22     35
# 9       4
# 252    56
# 63     56
# 12     36
# dtype: int64

# %%
s6[9]
# Out:
# 9    4
# 9    4
# dtype: int64

# %%
s6[0:6]
# Out:
# /tmp/ipykernel_126/4018399945.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   s6[0:6]
# 2      3
# 9      4
# 5      5
# 6      6
# 1      6
# 22    35
# dtype: int64

# %%
s4
# Out:
# 2    3
# 9    4
# 5    5
# 6    6
# 1    6
# dtype: int64

# %%
s5
# Out:
# 22     35
# 9       4
# 252    56
# 63     56
# 12     36
# dtype: int64

# %%
s4*s5
# Out:
# 1       NaN
# 2       NaN
# 5       NaN
# 6       NaN
# 9      16.0
# 12      NaN
# 22      NaN
# 63      NaN
# 252     NaN
# dtype: float64

# %%
s4+s5
# Out:
# 1      NaN
# 2      NaN
# 5      NaN
# 6      NaN
# 9      8.0
# 12     NaN
# 22     NaN
# 63     NaN
# 252    NaN
# dtype: float64

# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name')
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d={"key":[3,4,5,6,7],
   'key2':[5,6,7,7,6],
   'key3':[4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key  key2  key3
# 0    3     5     4
# 1    4     6     5
# 2    5     7     6
# 3    6     7     7
# 4    7     6     8

# %%
df1=pd.read_csv('HR_Analytics.csv')

# %%
df1
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
import pandas as pd

# %%
df1=pd.read_csv('taxonomy.csv')

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2.fillna("shibani")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency   shibani               shibani
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
g=df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_126/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_126/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1=df.groupby('Pclass')

# %%
g1.sum()
# Out:
# /tmp/ipykernel_126/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_126/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()['Name'].T
# Out:
# /tmp/ipykernel_126/2485502036.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Name'].T
# Pclass
# 1       Young, Miss. Marie Grice
# 2      del Carlo, Mr. Sebastiano
# 3    van Melkebeke, Mr. Philemon
# Name: Name, dtype: object

# %%
g1.max().T
# Out:
# /tmp/ipykernel_126/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df5=df[['Survived','Pclass','Name']][0:5]

# %%
df6=df[['Survived','Pclass','Name']][5:10]

# %%
df5
# Out:
#    Survived  Pclass                                               Name
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         0       3                           Allen, Mr. William Henry
# 4         0       3                                   Moran, Mr. James

# %%
df6
# Out:
#    Survived  Pclass                                               Name
# 5         0       1                            McCarthy, Mr. Timothy J
# 6         0       3                     Palsson, Master. Gosta Leonard
# 7         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 9         1       3                    Sandstrom, Miss. Marguerite Rut

# %%
pd.concat([df5,df6])
# Out:
#    Survived  Pclass                                               Name
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         0       3                           Allen, Mr. William Henry
# 4         0       3                                   Moran, Mr. James
# 5         0       1                            McCarthy, Mr. Timothy J
# 6         0       3                     Palsson, Master. Gosta Leonard
# 7         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 9         1       3                    Sandstrom, Miss. Marguerite Rut

# %%
df7=pd.concat([df5,df6],axis=1)

# %%
df7.fillna('shiabnI')
# Out:
#   Survived   Pclass                                               Name  \
# 0      0.0      3.0                            Braund, Mr. Owen Harris
# 1      1.0      1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      1.0      3.0                             Heikkinen, Miss. Laina
# 3      0.0      3.0                           Allen, Mr. William Henry
# 4      0.0      3.0                                   Moran, Mr. James
# 5  shiabnI  shiabnI                                            shiabnI
# 6  shiabnI  shiabnI                                            shiabnI
# 7  shiabnI  shiabnI                                            shiabnI
# 8  shiabnI  shiabnI                                            shiabnI
# 9  shiabnI  shiabnI                                            shiabnI
#
#   Survived   Pclass                                               Name
# 0  shiabnI  shiabnI                                            shiabnI
# ...

# %%
data1=pd.DataFrame({'key1':[1,2,3,4,6],
                    'key2':[4,5,6,7,6],
                    'key3':[3,4,5,6,6]
})

# %%
data2=pd.DataFrame({'key1':[1,2,35,43,6],
                    'key4':[45,52,6,7,6],
                    'key5':[3,4,56,69,66]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     6     6     6

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    45     3
# 1     2    52     4
# 2    35     6    56
# 3    43     7    69
# 4     6     6    66

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    45     3
# 1     2     5     4    52     4
# 2     6     6     6     6    66

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  45.0   3.0
# 1     2     5     4  52.0   4.0
# 2     3     6     5   NaN   NaN
# 3     4     7     6   NaN   NaN
# 4     6     6     6   6.0  66.0

# %%
pd.merge(data1,data2,how='outer',on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  45.0   3.0
# 1     2   5.0   4.0  52.0   4.0
# 2     3   6.0   5.0   NaN   NaN
# 3     4   7.0   6.0   NaN   NaN
# 4     6   6.0   6.0   6.0  66.0
# 5    35   NaN   NaN   6.0  56.0
# 6    43   NaN   NaN   7.0  69.0

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    45     3
# 1        1     4     3       2    52     4
# 2        1     4     3      35     6    56
# 3        1     4     3      43     7    69
# 4        1     4     3       6     6    66
# 5        2     5     4       1    45     3
# 6        2     5     4       2    52     4
# 7        2     5     4      35     6    56
# 8        2     5     4      43     7    69
# 9        2     5     4       6     6    66
# 10       3     6     5       1    45     3
# 11       3     6     5       2    52     4
# 12       3     6     5      35     6    56
# 13       3     6     5      43     7    69
# 14       3     6     5       6     6    66
# 15       4     7     6       1    45     3
# 16       4     7     6       2    52     4
# 17       4     7     6      35     6    56
# 18       4     7     6      43     7    69
# 19       4     7     6       6     6    66
# 20       6     6     6       1    45     3
# ...

# %%
#join

# %%
data1=pd.DataFrame({'key1':[1,2,3,4,6],
                    'key2':[4,5,6,7,6],
                    'key3':[3,4,5,6,6]},
                   index=['a','b','c','d','e']
                  )

# %%
data2=pd.DataFrame({'key11':[1,2,35,43,6],
                    'key4':[45,52,6,7,6],
                    'key53':[3,4,56,69,66]},
                   index=['a','b','h','i','j']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     3     6     5
# d     4     7     6
# e     6     6     6

# %%
data2
# Out:
#    key11  key4  key53
# a      1    45      3
# b      2    52      4
# h     35     6     56
# i     43     7     69
# j      6     6     66

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key4  key53
# a     1     4     3    1.0  45.0    3.0
# b     2     5     4    2.0  52.0    4.0
# c     3     6     5    NaN   NaN    NaN
# d     4     7     6    NaN   NaN    NaN
# e     6     6     6    NaN   NaN    NaN

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key4  key53
# a   1.0   4.0   3.0      1    45      3
# b   2.0   5.0   4.0      2    52      4
# h   NaN   NaN   NaN     35     6     56
# i   NaN   NaN   NaN     43     7     69
# j   NaN   NaN   NaN      6     6     66

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key4  key53
# a     1     4     3      1    45      3
# b     2     5     4      2    52      4

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key4  key53
# a   1.0   4.0   3.0    1.0  45.0    3.0
# b   2.0   5.0   4.0    2.0  52.0    4.0
# c   3.0   6.0   5.0    NaN   NaN    NaN
# d   4.0   7.0   6.0    NaN   NaN    NaN
# e   6.0   6.0   6.0    NaN   NaN    NaN
# h   NaN   NaN   NaN   35.0   6.0   56.0
# i   NaN   NaN   NaN   43.0   7.0   69.0
# j   NaN   NaN   NaN    6.0   6.0   66.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key4  key53
# 0      1     4     3      1    45      3
# 1      1     4     3      2    52      4
# 2      1     4     3     35     6     56
# 3      1     4     3     43     7     69
# 4      1     4     3      6     6     66
# 5      2     5     4      1    45      3
# 6      2     5     4      2    52      4
# 7      2     5     4     35     6     56
# 8      2     5     4     43     7     69
# 9      2     5     4      6     6     66
# 10     3     6     5      1    45      3
# 11     3     6     5      2    52      4
# 12     3     6     5     35     6     56
# 13     3     6     5     43     7     69
# 14     3     6     5      6     6     66
# 15     4     7     6      1    45      3
# 16     4     7     6      2    52      4
# 17     4     7     6     35     6     56
# 18     4     7     6     43     7     69
# 19     4     7     6      6     6     66
# 20     6     6     6      1    45      3
# 21     6     6     6      2    52      4
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['Fare_INR']=df['Fare'].apply(lambda x: x*80)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['name_len']=df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR  name_len
# 0   580.000        23
# 1  5702.664        51
# 2   634.000        22
# ...

# %%
#day5

# %%
import pandas as pd

# %%
data={"a":[1,2,3,4],
     "b":[4,5,6,7],
     "c":["shibani","sankar","nayak","guddu"]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    a  b        c
# 0  1  4  shibani
# 1  2  5   sankar
# 2  3  6    nayak
# 3  4  7    guddu

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#    b        c
# a
# 1  4  shibani
# 2  5   sankar
# 3  6    nayak
# 4  7    guddu

# %%
df=df.reset_index()

# %%
data={"a":[1,2,3,4],
     "b":[4,5,6,7],
     "c":["shibani","sankar","nayak","guddu"]}
df1=pd.DataFrame(data,index=['a','b','c','d'])

# %% [markdown]
# df1

# %%
df1
# Out:
#    a  b        c
# a  1  4  shibani
# b  2  5   sankar
# c  3  6    nayak
# d  4  7    guddu

# %%
df1.reindex(['b','c','d','a'])
# Out:
#    a  b        c
# b  2  5   sankar
# c  3  6    nayak
# d  4  7    guddu
# a  1  4  shibani

# %%
for i in df1.iterrows():
    print(i)
# Out:
# ('a', a          1
# b          4
# c    shibani
# Name: a, dtype: object)
# ('b', a         2
# b         5
# c    sankar
# Name: b, dtype: object)
# ('c', a        3
# b        6
# c    nayak
# Name: c, dtype: object)
# ('d', a        4
# b        7
# c    guddu
# Name: d, dtype: object)

# %%
for i in df1.iteritems():
    print(i)
# Out:
# ('a', a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64)
# ('b', a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64)
# ('c', a    shibani
# b     sankar
# c      nayak
# d      guddu
# Name: c, dtype: object)
# /tmp/ipykernel_112/549805685.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i in df1.iteritems():

# %%
df1
# Out:
#    a  b        c
# a  1  4  shibani
# b  2  5   sankar
# c  3  6    nayak
# d  4  7    guddu

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
df1
# Out:
#    a  b        c
# a  1  4  shibani
# b  2  5   sankar
# c  3  6    nayak
# d  4  7    guddu

# %%
def test(x):
    return x.sum()
df1.apply(test)
# Out:
# a                         10
# b                         22
# c    shibanisankarnayakguddu
# dtype: object

# %%
df2=df1[['a','b']]

# %%
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x:x**2)
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
df1
# Out:
#    a  b        c
# a  1  4  shibani
# b  2  5   sankar
# c  3  6    nayak
# d  4  7    guddu

# %%
df
# Out:
#    a  b        c
# 0  1  4  shibani
# 1  2  5   sankar
# 2  3  6    nayak
# 3  4  7    guddu

# %%
df.sort_values('c')
# Out:
#    a  b        c
# 3  4  7    guddu
# 2  3  6    nayak
# 1  2  5   sankar
# 0  1  4  shibani

# %%
df.sort_index(ascending=False)
# Out:
#    a  b        c
# 3  4  7    guddu
# 2  3  6    nayak
# 1  2  5   sankar
# 0  1  4  shibani

# %%
df.sort_index()
# Out:
#    a  b        c
# 0  1  4  shibani
# 1  2  5   sankar
# 2  3  6    nayak
# 3  4  7    guddu

# %%
pd.set_option("display.max_colwidth" ,500)
df3=pd.DataFrame({"desc":["To solve this problem, we can use a Python dictionary to keep track of the elements we have seen so far. We will iterate through the input list, and if an element is not in the dictionary, we will add it to the dictionary and also add it to the result list. If the element is already in the dictionary, it means it's a duplicate, and we can skip it."]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                             desc
# 0  To solve this problem, we can use a Python dictionary to keep track of the elements we have seen so far. We will iterate through the input list, and if an element is not in the dictionary, we will add it to the dictionary and also add it to the result list. If the element is already in the dictionary, it means it's a duplicate, and we can skip it.

# %%
pd.set_option("display.max_colwidth" ,500)
df3=pd.DataFrame({"desc":["To solve this problem, we can use a Python dictionary to keep track of the elements we have seen so far. We will iterate through the input list, and if an element is not in the dictionary, we will add it to the dictionary and also add it to the result list. If the element is already in the dictionary, it means it's a duplicate, and we can skip it.","my anme is shibani ","i well  w "]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                             desc
# 0  To solve this problem, we can use a Python dictionary to keep track of the elements we have seen so far. We will iterate through the input list, and if an element is not in the dictionary, we will add it to the dictionary and also add it to the result list. If the element is already in the dictionary, it means it's a duplicate, and we can skip it.
# ...

# %%
df3['len']=df3['Desc'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Desc'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
t= "i use to teach data scince"
len(t.split())
# Out:
# 6

# %%
df['word_count']=df3['Desc'].apply(lambda x:len(x.split()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Desc'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#    a  b        c
# 0  1  4  shibani
# 1  2  5   sankar
# 2  3  6    nayak
# 3  4  7    guddu

# %%
df['a'][0]
# Out:
# 1

# %%
df
# Out:
#    a  b        c
# 0  1  4  shibani
# 1  2  5   sankar
# 2  3  6    nayak
# 3  4  7    guddu

# %%
df['a'].mean()
# Out:
# 2.5

# %%
df['a'].median()
# Out:
# 2.5

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()
# Out:
# 1.2909944487358056

# %%
df['a'].sum()
# Out:
# 10

# %%
df['a'].min()
# Out:
# 1

# %%
df['a'].max()
# Out:
# 4

# %%
df['a'].var()
# Out:
# 1.6666666666666667

# %%
df4=pd.DataFrame({'a':[3,6,5,5,3,6,4,8,2,52,9]})

# %%
df4
# Out:
#      a
# 0    3
# 1    6
# 2    5
# 3    5
# 4    3
# 5    6
# 6    4
# 7    8
# 8    2
# 9   52
# 10   9

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0      3.0
# 1      6.0
# 2      5.0
# 3      5.0
# 4      3.0
# 5      6.0
# 6      4.0
# 7      8.0
# 8      2.0
# 9     52.0
# 10     9.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0      NaN
# 1      4.5
# 2      5.5
# 3      5.0
# 4      4.0
# 5      4.5
# 6      5.0
# 7      6.0
# 8      5.0
# 9     27.0
# 10    30.5
# Name: a, dtype: float64

# %%
#camnutem sum

# %%
df4['a'].cumsum()
# Out:
# 0       3
# 1       9
# 2      14
# 3      19
# 4      22
# 5      28
# 6      32
# 7      40
# 8      42
# 9      94
# 10    103
# Name: a, dtype: int64

# %%
#data fancl=tiondity
data=pd.date_range(start='2023-04-23',end='2023-06-8')

# %%
data
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date=pd.DataFrame({'data':data})

# %%
df_date
# Out:
#          data
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# 5  2023-04-28
# 6  2023-04-29
# 7  2023-04-30
# 8  2023-05-01
# 9  2023-05-02
# 10 2023-05-03
# 11 2023-05-04
# 12 2023-05-05
# 13 2023-05-06
# 14 2023-05-07
# 15 2023-05-08
# 16 2023-05-09
# 17 2023-05-10
# 18 2023-05-11
# 19 2023-05-12
# 20 2023-05-13
# 21 2023-05-14
# 22 2023-05-15
# 23 2023-05-16
# 24 2023-05-17
# 25 2023-05-18
# 26 2023-05-19
# 27 2023-05-20
# 28 2023-05-21
# 29 2023-05-22
# 30 2023-05-23
# 31 2023-05-24
# 32 2023-05-25
# 33 2023-05-26
# 34 2023-05-27
# 35 2023-05-28
# 36 2023-05-29
# 37 2023-05-30
# 38 2023-05-31
# 39 2023-06-01
# 40 2023-06-02
# 41 2023-06-03
# 42 2023-06-04
# 43 2023-06-05
# 44 2023-06-06
# 45 2023-06-07
# 46 2023-06-08

# %%
#time delta

# %%
pd.Timedelta(days=1,hours=5,min=45)
Timedelta("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 pd.Timedelta(days=1,hours=5,min=45)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx:1636, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: cannot construct a Timedelta from the passed arguments, allowed keywords are [weeks, days, hours, minutes, seconds, milliseconds, microseconds, nanoseconds]

# %%
tt=pd.Timedelta(days=1)

# %%
dt+tt
# Out:
# Timedelta('2 days 00:00:00')

# %%
data=['shibani','sankar','nayak','guddu']

# %%
pd.CategoricalDtype(data)
# Out:
# CategoricalDtype(categories=['shibani', 'sankar', 'nayak', 'guddu'], ordered=False)

# %%
#pandas visualization

# %%
d=pd.Series([1,2,3,5,6,7,8,9])

# %%
d.plot()
# Out:
# <AxesSubplot: >

# %%
df=pd.DataFrame({'a':[1,2,7,4,5],
                'b':[5,6,7,8,9]})

# %%
df.plot(x='a',y='b')
# Out:
# <AxesSubplot: xlabel='a'>
